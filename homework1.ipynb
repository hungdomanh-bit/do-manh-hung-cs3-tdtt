# %% [markdown]
# <a href="https://colab.research.google.com/github/hungdomanh-bit/do-manh-hung-cs3-tdtt/blob/main/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#B1
so_nguyen = int(input('NHap vao 1 so nguyen n '))
print('2 lan so nguyen cua ban la : ' , 2* so_nguyen )
# Out:
# NHap vao 1 so nguyen n 2
# 2 lan so nguyen cua ban la :  4

# %%
#B2
chieu_rong = float(input('Hay nhap vao chieu rong khu dat: '))
chieu_dai = float(input('Hay nhap vao chieu dai khu dat: '))
s_conlai = (chieu_rong * chieu_dai) - 3.14 * (chieu_rong / 2) ** 2
print('Dien tich con lai de trong cay la: ' , s_conlai )
# Out:
# Hay nhap vao chieu rong khu dat: 4
# Hay nhap vao chieu dai khu dat: 6
# Dien tich con lai de trong cay la:  11.44

# %%
ki_tu = input()
if 97 <= ord(ki_tu) <= 122 :
  print(ki_tu.upper())
elif 65<= ord(ki_tu) <= 90 :
  print(ki_tu.lower())
else :
  print('M nhap sai yeu cau roi ')
# Out:
# A
# a

# %%
#B6
a , b , c = map(float , input('Nhap vao 3 so a , b , c ').split())
if a+b-c >0 and b+c-a>0 and c+a-b>0 :

    print('Day la 3 canh cua 1 tam giac')
else :
    print(' Day ko phai 3 canh 1 tam giac ')
# Out:
# Nhap vao 3 so a , b , c 4 5 6
# Day la 3 canh cua 1 tam giac

# %%
in_put =input('Nhap vao hon 20 ki tu ')
print(in_put[4] ,'va',  in_put[8])
# Out:
# Nhap vao hon 20 ki tu osjdojasoidjaosjdoijsaiodjaiosjdioajsiodjasiodjoaisjdiojsdaiojoia
# o va o

# %%
ten_chuho= input('Nhap vao ten chu ho: ')
sodien_thangtrc=float(input('Nhap vao so dien thang truoc: '))
sodien_thangnay = float(input('Nhap vao so dien thang nay: '))
sodien_cantra = sodien_thangtrc - sodien_thangnay
 if 0<= sodien_cantra<=50
  tiendien_chuaVAT = 1.984*sodien_cantra
 elif 51<= sodien_cantra   <=100
    tien_dien_chuaVa
 elif 101<=.   <= 200

 elif 201<=.   <=300

 elif 301<=.    <= 400

 else :

# %%
so_nhap = int(input('Nhap vao 1 so nguyen: '))
if so_nhap % 2 = 0 :
  print(' Day la 1 so chan ')
elif so_nhap % 2 = 1 :
  print('Day la 1 so le ')
else
