# %% [markdown]
# <a href="https://colab.research.google.com/github/hungdomanh-bit/do-manh-hung-cs3-tdtt/blob/main/Bieuthuctoantunxdl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#W2A1
print('Hello World!')
# Out:
# Hello World!

# %%
#W2A2
ten_nguoi = input('Ten ban la gi ? ')
print('Xin chao' ,ten_nguoi)
# Out:
# Ten ban la gi ? hung
# Xin chao hung

# %%
#W2A3
so_A = int(input('Nhap vao so a '))
so_B = int(input('Nhap vao so b '))
phan_nguyen = so_A // so_B
phan_du = so_A % so_B
achiab_lamtron = round(so_A / so_B , 2)
print('Phan du A la' ,phan_du , 'Phan nguyen la' ,phan_nguyen)
print(achiab_lamtron)
# Out:
# Nhap vao so a 5
# Nhap vao so b 4
# Phan du A la 1 Phan nguyen la 1
# 1.25

# %%
#W2A4
a1 , b1 , c1 ,a2 , b2 , a3 = map(float , input('Nhap diem vao theo thu tu  ').split())
diem_trungbinh = (a1+b1+c1+(a2+b2)*2+a3*3)/10
print('Diem trung binh la ',diem_trungbinh)
# Out:
# Nhap diem vao theo thu tu  5 4 3 2 1 1
# Diem trung binh la  2.1

# %%
#W2A5
a , b = map(int , input('Nhap vao 2 so a , b ').split())
ham_mu = a**b
print('a mu b bang' , ham_mu)
# Out:
# Nhap vao 2 so a , b 5 4
# a mu b bang 625

# %%
#W2A6
ki_tu = input('Nhap vao 1 ki tu ')
print('Ma Unicode cua ki tu  la ', ord(ki_tu))
print('In hoa ki tu cua ban : ' , chr(ord(ki_tu)-32))
# Out:
# Nhap vao 1 ki tu a
# Ma Unicode cua ki tu  la  97
# In hoa ki tu cua ban :  A

# %%
#W2A7

# %%
#W2A8
do_celcius = int(input('Nhap vao do celcius '))
do_F = 9/5 * do_celcius + 32
print('Do Celcius cua ban khi doi sang do F la : ' , do_F)
# Out:
# Nhap vao do celcius 56
# Do Celcius cua ban khi doi sang do F la :  132.8

# %%
print('### # #   ### ###\n #  #  #   #   #\n #  #   #  #   #\n #  #  #   #   #\n #  # #    #   # ')
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
chuoi_can_in = "Hello World\n"
# "\n" là ký tự xuống dòng, đảm bảo mỗi lần lặp nằm trên một dòng mới

# In chuỗi lặp lại 10 lần
print(chuoi_can_in * 10)
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
