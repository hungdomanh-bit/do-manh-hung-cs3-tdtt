# %% [markdown]
# <a href="https://colab.research.google.com/github/hungdomanh-bit/do-manh-hung-cs3-tdtt/blob/main/list_%2C_tuple_%2C_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#list
ten_hocsinh = [ Hung , Do , Manh ]
#tuple
diem_thi = ( 9 , 6 , 6 )
#dictionary
thong_tin = { ' Khoi' : ' Chim Hoi ' , 'diem' : 1 }

# %%
thu_muc = [ ' Ky ' , ' An ' , 'Cut' ]
print(thu_muc[0])
thu_muc.insert(  2 , ' Tao ') # add before index[]
thu_muc.append # add to end
thu_muc.remove('Ky') # remove by value
thu_muc.pop(1) # remove by index
thu_muc.reverse # reverse order
thu_muc.sort # sort ascending
# Out:
#  Ky
# [' Ky ', ' An ', ' Tao ', 'Cut']

# %%
#Exercise
diem_thi = [9.5 , 8.0 , 7.0 , 10.0]
print( diem_thi[0] , ' and ' , diem_thi[3])
diem_thi.append(9.0)
diem_thi.sort()
diem_thi.reverse()
print(diem_thi)
# Out:
# 9.5  and  10.0
# [10.0, 9.5, 9.0, 8.0, 7.0]

# %%
#tuple
# cannot be changed after creation
# Out:
# (10, 20)

# %%
import math
def check_squareNumber2(x):
    i = math.isqrt(x)
    return (i*i == x)
print(check_squareNumber2(12))
# Out:
# False
